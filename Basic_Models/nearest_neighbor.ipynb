# %% [markdown]
# # Nearest Neighbor Basic - Tensorflow

# %%
import numpy as np
import tensorflow as tf

#import mnist dataset
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("/tmp/data", one_hot= True)
# Out:
# WARNING:tensorflow:From <ipython-input-2-a28dcbad66ca>:6: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From C:\Users\kulde\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From C:\Users\kulde\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\base.py:252: _internal_retry.<locals>.wrap.<locals>.wrapped_fn (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use urllib or similar directly.
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# WARNING:tensorflow:From C:\Users\kulde\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting /tmp/data\train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# WARNING:tensorflow:From C:\Users\kulde\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting /tmp/data\train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From C:\Users\kulde\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting /tmp/data\t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting /tmp/data\t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From C:\Users\kulde\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %%
X_train, Y_train = mnist.train.next_batch(5000)
X_test, Y_test = mnist.test.next_batch(200)

# %%
xtrain = tf.placeholder(tf.float64, [None, 784])
xtest = tf.placeholder(tf.float64, [784])

# %%
#Nearest neighbor model, we will calculate L1 distance
dist = tf.reduce_sum(tf.abs(tf.add(xtrain, tf.negative(xtest))), reduction_indices=1)
pred = tf.argmin(dist, 0)

# %%
acc = 0.

init = tf.global_variables_initializer()

# %%
with tf.Session() as sess:
    
    sess.run(init)
    
    for i in range(len(X_test)):
        
        nn_index = sess.run(pred, feed_dict={xtrain: X_train, xtest:X_test[i, :]})
        
        print("Test: ", i, " Prediction: ", np.argmax(Y_train[nn_index]), " True_class: ", np.argmax(Y_test[i]))
        
        if np.argmax(Y_train[nn_index]) == np.argmax(Y_test[i]):
            acc += 1./len(X_test)
        
        
    print("Accuracy: ", acc)
# Out:
# Test:  0  Prediction:  4  True_class:  4
# Test:  1  Prediction:  0  True_class:  0
# Test:  2  Prediction:  3  True_class:  5
# Test:  3  Prediction:  3  True_class:  3
# Test:  4  Prediction:  4  True_class:  4
# Test:  5  Prediction:  8  True_class:  8
# Test:  6  Prediction:  1  True_class:  1
# Test:  7  Prediction:  2  True_class:  2
# Test:  8  Prediction:  9  True_class:  9
# Test:  9  Prediction:  5  True_class:  5
# Test:  10  Prediction:  7  True_class:  7
# Test:  11  Prediction:  6  True_class:  6
# Test:  12  Prediction:  5  True_class:  5
# Test:  13  Prediction:  7  True_class:  7
# Test:  14  Prediction:  8  True_class:  8
# Test:  15  Prediction:  2  True_class:  3
# Test:  16  Prediction:  0  True_class:  0
# Test:  17  Prediction:  4  True_class:  4
# Test:  18  Prediction:  1  True_class:  1
# Test:  19  Prediction:  4  True_class:  9
# Test:  20  Prediction:  9  True_class:  9
# Test:  21  Prediction:  5  True_class:  5
# Test:  22  Prediction:  3  True_class:  3
# Test:  23  Prediction:  1  True_class:  1
# Test:  24  Prediction:  6  True_class:  5
# Test:  25  Prediction:  4  True_class:  4
# Test:  26  Prediction:  3  True_class:  3
# Test:  27  Prediction:  2  True_class:  2
# Test:  28  Prediction:  2  True_class:  2
# Test:  29  Prediction:  7  True_class:  9
# Test:  30  Prediction:  6  True_class:  6
# Test:  31  Prediction:  0  True_class:  9
# Test:  32  Prediction:  4  True_class:  4
# Test:  33  Prediction:  7  True_class:  7
# Test:  34  Prediction:  4  True_class:  4
# Test:  35  Prediction:  0  True_class:  0
# Test:  36  Prediction:  4  True_class:  4
# Test:  37  Prediction:  2  True_class:  2
# Test:  38  Prediction:  8  True_class:  8
# Test:  39  Prediction:  5  True_class:  5
# Test:  40  Prediction:  2  True_class:  2
# Test:  41  Prediction:  9  True_class:  9
# Test:  42  Prediction:  9  True_class:  9
# Test:  43  Prediction:  8  True_class:  8
# Test:  44  Prediction:  5  True_class:  5
# Test:  45  Prediction:  6  True_class:  6
# Test:  46  Prediction:  8  True_class:  8
# Test:  47  Prediction:  2  True_class:  2
# Test:  48  Prediction:  2  True_class:  2
# Test:  49  Prediction:  3  True_class:  3
# Test:  50  Prediction:  7  True_class:  7
# Test:  51  Prediction:  9  True_class:  9
# Test:  52  Prediction:  9  True_class:  9
# Test:  53  Prediction:  3  True_class:  3
# Test:  54  Prediction:  3  True_class:  3
# Test:  55  Prediction:  7  True_class:  7
# Test:  56  Prediction:  5  True_class:  5
# Test:  57  Prediction:  4  True_class:  4
# Test:  58  Prediction:  6  True_class:  6
# Test:  59  Prediction:  4  True_class:  4
# Test:  60  Prediction:  6  True_class:  6
# Test:  61  Prediction:  1  True_class:  1
# Test:  62  Prediction:  1  True_class:  1
# Test:  63  Prediction:  5  True_class:  5
# Test:  64  Prediction:  7  True_class:  7
# Test:  65  Prediction:  5  True_class:  5
# Test:  66  Prediction:  1  True_class:  1
# Test:  67  Prediction:  6  True_class:  6
# Test:  68  Prediction:  5  True_class:  5
# Test:  69  Prediction:  0  True_class:  0
# Test:  70  Prediction:  4  True_class:  4
# Test:  71  Prediction:  4  True_class:  4
# Test:  72  Prediction:  3  True_class:  3
# Test:  73  Prediction:  6  True_class:  6
# Test:  74  Prediction:  3  True_class:  3
# Test:  75  Prediction:  6  True_class:  6
# Test:  76  Prediction:  3  True_class:  3
# Test:  77  Prediction:  7  True_class:  7
# Test:  78  Prediction:  7  True_class:  7
# Test:  79  Prediction:  0  True_class:  0
# Test:  80  Prediction:  4  True_class:  4
# Test:  81  Prediction:  7  True_class:  7
# Test:  82  Prediction:  6  True_class:  6
# Test:  83  Prediction:  8  True_class:  8
# Test:  84  Prediction:  7  True_class:  7
# Test:  85  Prediction:  9  True_class:  9
# Test:  86  Prediction:  5  True_class:  5
# Test:  87  Prediction:  4  True_class:  4
# Test:  88  Prediction:  3  True_class:  3
# Test:  89  Prediction:  9  True_class:  9
# Test:  90  Prediction:  5  True_class:  8
# Test:  91  Prediction:  1  True_class:  1
# Test:  92  Prediction:  1  True_class:  1
# Test:  93  Prediction:  0  True_class:  0
# Test:  94  Prediction:  8  True_class:  8
# Test:  95  Prediction:  3  True_class:  3
# Test:  96  Prediction:  3  True_class:  3
# Test:  97  Prediction:  7  True_class:  7
# Test:  98  Prediction:  2  True_class:  2
# Test:  99  Prediction:  4  True_class:  9
# Test:  100  Prediction:  5  True_class:  5
# Test:  101  Prediction:  5  True_class:  5
# Test:  102  Prediction:  5  True_class:  5
# Test:  103  Prediction:  7  True_class:  7
# Test:  104  Prediction:  8  True_class:  8
# Test:  105  Prediction:  0  True_class:  0
# Test:  106  Prediction:  0  True_class:  0
# Test:  107  Prediction:  8  True_class:  8
# Test:  108  Prediction:  1  True_class:  2
# Test:  109  Prediction:  1  True_class:  1
# Test:  110  Prediction:  6  True_class:  6
# Test:  111  Prediction:  0  True_class:  0
# Test:  112  Prediction:  2  True_class:  2
# Test:  113  Prediction:  1  True_class:  1
# Test:  114  Prediction:  7  True_class:  7
# Test:  115  Prediction:  9  True_class:  9
# Test:  116  Prediction:  7  True_class:  7
# Test:  117  Prediction:  2  True_class:  2
# Test:  118  Prediction:  3  True_class:  3
# Test:  119  Prediction:  3  True_class:  8
# Test:  120  Prediction:  3  True_class:  3
# Test:  121  Prediction:  8  True_class:  8
# Test:  122  Prediction:  3  True_class:  3
# Test:  123  Prediction:  4  True_class:  4
# Test:  124  Prediction:  2  True_class:  2
# Test:  125  Prediction:  8  True_class:  6
# Test:  126  Prediction:  7  True_class:  7
# Test:  127  Prediction:  2  True_class:  2
# Test:  128  Prediction:  8  True_class:  8
# Test:  129  Prediction:  6  True_class:  6
# Test:  130  Prediction:  7  True_class:  7
# Test:  131  Prediction:  4  True_class:  4
# Test:  132  Prediction:  2  True_class:  4
# Test:  133  Prediction:  5  True_class:  5
# Test:  134  Prediction:  5  True_class:  5
# Test:  135  Prediction:  8  True_class:  8
# Test:  136  Prediction:  3  True_class:  3
# Test:  137  Prediction:  5  True_class:  5
# Test:  138  Prediction:  3  True_class:  3
# Test:  139  Prediction:  5  True_class:  5
# Test:  140  Prediction:  9  True_class:  9
# Test:  141  Prediction:  3  True_class:  3
# Test:  142  Prediction:  4  True_class:  4
# Test:  143  Prediction:  6  True_class:  6
# Test:  144  Prediction:  0  True_class:  0
# Test:  145  Prediction:  7  True_class:  7
# Test:  146  Prediction:  6  True_class:  6
# Test:  147  Prediction:  1  True_class:  1
# Test:  148  Prediction:  2  True_class:  2
# Test:  149  Prediction:  1  True_class:  1
# Test:  150  Prediction:  6  True_class:  6
# Test:  151  Prediction:  7  True_class:  7
# Test:  152  Prediction:  2  True_class:  2
# Test:  153  Prediction:  4  True_class:  4
# Test:  154  Prediction:  4  True_class:  4
# Test:  155  Prediction:  5  True_class:  5
# Test:  156  Prediction:  3  True_class:  3
# Test:  157  Prediction:  0  True_class:  0
# Test:  158  Prediction:  5  True_class:  5
# Test:  159  Prediction:  2  True_class:  2
# Test:  160  Prediction:  4  True_class:  4
# Test:  161  Prediction:  0  True_class:  0
# Test:  162  Prediction:  2  True_class:  2
# Test:  163  Prediction:  6  True_class:  6
# Test:  164  Prediction:  2  True_class:  2
# Test:  165  Prediction:  0  True_class:  0
# Test:  166  Prediction:  9  True_class:  5
# Test:  167  Prediction:  1  True_class:  1
# Test:  168  Prediction:  1  True_class:  2
# Test:  169  Prediction:  3  True_class:  3
# Test:  170  Prediction:  1  True_class:  1
# Test:  171  Prediction:  4  True_class:  4
# Test:  172  Prediction:  4  True_class:  4
# Test:  173  Prediction:  2  True_class:  2
# Test:  174  Prediction:  1  True_class:  1
# Test:  175  Prediction:  3  True_class:  3
# Test:  176  Prediction:  9  True_class:  9
# Test:  177  Prediction:  8  True_class:  8
# Test:  178  Prediction:  9  True_class:  9
# Test:  179  Prediction:  6  True_class:  6
# Test:  180  Prediction:  5  True_class:  5
# Test:  181  Prediction:  3  True_class:  3
# Test:  182  Prediction:  8  True_class:  8
# Test:  183  Prediction:  1  True_class:  1
# Test:  184  Prediction:  7  True_class:  7
# Test:  185  Prediction:  7  True_class:  7
# Test:  186  Prediction:  8  True_class:  8
# Test:  187  Prediction:  4  True_class:  4
# Test:  188  Prediction:  1  True_class:  1
# Test:  189  Prediction:  3  True_class:  3
# Test:  190  Prediction:  7  True_class:  7
# Test:  191  Prediction:  2  True_class:  2
# Test:  192  Prediction:  2  True_class:  2
# Test:  193  Prediction:  7  True_class:  7
# Test:  194  Prediction:  8  True_class:  8
# Test:  195  Prediction:  2  True_class:  2
# Test:  196  Prediction:  2  True_class:  2
# Test:  197  Prediction:  5  True_class:  5
# Test:  198  Prediction:  6  True_class:  6
# Test:  199  Prediction:  7  True_class:  3
# Accuracy:  0.9250000000000007
